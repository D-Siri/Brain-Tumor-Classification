# %%
import os
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

dataset_path = '/Users/siriduggineni/Downloads/archive (9)/'
train_path = os.path.join(dataset_path, 'training')
test_path = os.path.join(dataset_path, 'testing')

train_images = []
train_labels = []
for folder_name in os.listdir(train_path):
    folder_path = os.path.join(train_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        train_images.append(image_path)
        train_labels.append(folder_name)



test_images = []
test_labels = []
for folder_name in os.listdir(test_path):
    folder_path = os.path.join(test_path, folder_name)
    for image_name in os.listdir(folder_path):
        image_path = os.path.join(folder_path, image_name)
        test_images.append(image_path)
        test_labels.append(folder_name)


all_images = train_images + test_images
all_labels = train_labels + test_labels


combined_data = list(zip(all_images, all_labels))
np.random.shuffle(combined_data)
all_images, all_labels = zip(*combined_data)

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

# %%
import cv2
import matplotlib.pyplot as plt


def display_sample_images(image_paths, labels, num_samples=5):
    fig, axes = plt.subplots(1, num_samples, figsize=(15, 3))
    for i in range(num_samples):
        image = cv2.imread(image_paths[i])
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        axes[i].imshow(image)
        axes[i].set_title(labels[i])
        axes[i].axis('off')
    plt.show()


print("Sample images from the training set:")
display_sample_images(train_images, train_labels)

print("Sample images from the validation set:")
display_sample_images(val_images, val_labels)

print("Sample images from the test set:")
display_sample_images(test_images, test_labels)
# Out:
# Sample images from the training set:
# Sample images from the validation set:
# Sample images from the test set:

# %%
import matplotlib.pyplot as plt

class_counts_train = {label: train_labels.count(label) for label in set(train_labels)}
class_counts_test = {label: test_labels.count(label) for label in set(test_labels)}

plt.figure(figsize=(12, 6))
plt.bar(class_counts_train.keys(), class_counts_train.values(), alpha=0.5, color='blue', label='Train')
plt.bar(class_counts_test.keys(), class_counts_test.values(), alpha=0.5, color='red', label='Test')
plt.xlabel('Classes')
plt.ylabel('Number of Images')
plt.title('Class Distribution')
plt.xticks(rotation=45)
plt.legend()
plt.show()

# %%
from sklearn.model_selection import train_test_split

train_images, val_test_images, train_labels, val_test_labels = train_test_split(all_images, all_labels, test_size=0.2, random_state=42)
val_images, test_images, val_labels, test_labels = train_test_split(val_test_images, val_test_labels, test_size=0.5, random_state=42)

from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.utils import to_categorical

label_encoder = LabelEncoder()
train_labels_encoded = label_encoder.fit_transform(train_labels)
val_labels_encoded = label_encoder.transform(val_labels)
test_labels_encoded = label_encoder.transform(test_labels)

y_train = to_categorical(train_labels_encoded)
y_val = to_categorical(val_labels_encoded)
y_test = to_categorical(test_labels_encoded)
img_width = 150
img_height = 150
def load_images(image_paths):
    images = []
    for image_path in image_paths:
        image = cv2.imread(image_path)
        image = cv2.resize(image, (img_width, img_height))
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        images.append(image)
    return np.array(images)

train_images_array = load_images(train_images)
val_images_array = load_images(val_images)
test_images_array = load_images(test_images)

X_train = train_images_array / 255.0
X_val = val_images_array / 255.0
X_test = test_images_array / 255.0

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.layers import Resizing

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, SpatialDropout1D, Embedding, Conv2D, MaxPooling2D, Flatten, Reshape

model = Sequential()

model.add(Conv2D(64, (3, 3), padding='same', input_shape=(150, 150, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Reshape((75, 75*64)))  

model.add(LSTM(64, return_sequences=True))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(32, return_sequences=True))
model.add(LSTM(16))

model.add(Dense(4, activation='softmax'))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_19 (Conv2D)          (None, 150, 150, 64)      1792
#
#  max_pooling2d_19 (MaxPooli  (None, 75, 75, 64)        0
#  ng2D)
#
#  reshape_1 (Reshape)         (None, 75, 4800)          0
#
#  lstm_13 (LSTM)              (None, 75, 64)            1245440
#
#  spatial_dropout1d_2 (Spati  (None, 75, 64)            0
#  alDropout1D)
#
#  lstm_14 (LSTM)              (None, 75, 32)            12416
#
#  lstm_15 (LSTM)              (None, 16)                3136
#
#  dense_8 (Dense)             (None, 4)                 68
#
# =================================================================
# Total params: 1262852 (4.82 MB)
# Trainable params: 1262852 (4.82 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.compile(loss='categorical_crossentropy',optimizer = 'Adam', metrics= ['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from torch.optim.lr_scheduler import ReduceLROnPlateau

checkpoint = ModelCheckpoint("bestomodel_LSTM.h5",monitor="val_accuracy",save_best_only=True,mode="auto",verbose=1)

# %%
history = model.fit(X_train, y_train, validation_data=(X_val, y_val), epochs =50, verbose=1, batch_size=64, callbacks=[checkpoint])
# Out:
# Epoch 1/50
# 41/41 [==============================] - ETA: 0s - loss: 1.2739 - accuracy: 0.4079
# Epoch 1: val_accuracy improved from -inf to 0.44172, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 43s 997ms/step - loss: 1.2739 - accuracy: 0.4079 - val_loss: 1.1857 - val_accuracy: 0.4417
# Epoch 2/50
# /Applications/anaconda3/lib/python3.11/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 41/41 [==============================] - ETA: 0s - loss: 1.0963 - accuracy: 0.5205
# Epoch 2: val_accuracy improved from 0.44172 to 0.52147, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 40s 973ms/step - loss: 1.0963 - accuracy: 0.5205 - val_loss: 1.0211 - val_accuracy: 0.5215
# Epoch 3/50
# 41/41 [==============================] - ETA: 0s - loss: 0.9428 - accuracy: 0.6113
# Epoch 3: val_accuracy improved from 0.52147 to 0.61963, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 36s 876ms/step - loss: 0.9428 - accuracy: 0.6113 - val_loss: 0.8755 - val_accuracy: 0.6196
# Epoch 4/50
# 41/41 [==============================] - ETA: 0s - loss: 0.8497 - accuracy: 0.6572
# Epoch 4: val_accuracy improved from 0.61963 to 0.64417, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 36s 877ms/step - loss: 0.8497 - accuracy: 0.6572 - val_loss: 0.8709 - val_accuracy: 0.6442
# Epoch 5/50
# 41/41 [==============================] - ETA: 0s - loss: 0.7896 - accuracy: 0.6856
# Epoch 5: val_accuracy improved from 0.64417 to 0.68098, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 33s 792ms/step - loss: 0.7896 - accuracy: 0.6856 - val_loss: 0.7780 - val_accuracy: 0.6810
# Epoch 6/50
# 41/41 [==============================] - ETA: 0s - loss: 0.7223 - accuracy: 0.7204
# Epoch 6: val_accuracy improved from 0.68098 to 0.73006, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 35s 864ms/step - loss: 0.7223 - accuracy: 0.7204 - val_loss: 0.7037 - val_accuracy: 0.7301
# Epoch 7/50
# 41/41 [==============================] - ETA: 0s - loss: 0.6815 - accuracy: 0.7281
# Epoch 7: val_accuracy did not improve from 0.73006
# 41/41 [==============================] - 35s 835ms/step - loss: 0.6815 - accuracy: 0.7281 - val_loss: 0.7339 - val_accuracy: 0.7178
# Epoch 8/50
# 41/41 [==============================] - ETA: 0s - loss: 0.6554 - accuracy: 0.7472
# Epoch 8: val_accuracy did not improve from 0.73006
# 41/41 [==============================] - 32s 789ms/step - loss: 0.6554 - accuracy: 0.7472 - val_loss: 0.6796 - val_accuracy: 0.7239
# Epoch 9/50
# 41/41 [==============================] - ETA: 0s - loss: 0.6240 - accuracy: 0.7591
# Epoch 9: val_accuracy did not improve from 0.73006
# 41/41 [==============================] - 26s 632ms/step - loss: 0.6240 - accuracy: 0.7591 - val_loss: 0.6911 - val_accuracy: 0.7270
# Epoch 10/50
# 41/41 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.7614
# Epoch 10: val_accuracy did not improve from 0.73006
# 41/41 [==============================] - 26s 630ms/step - loss: 0.6039 - accuracy: 0.7614 - val_loss: 0.6761 - val_accuracy: 0.7209
# Epoch 11/50
# 41/41 [==============================] - ETA: 0s - loss: 0.5583 - accuracy: 0.7871
# Epoch 11: val_accuracy did not improve from 0.73006
# 41/41 [==============================] - 34s 821ms/step - loss: 0.5583 - accuracy: 0.7871 - val_loss: 0.6369 - val_accuracy: 0.7301
# Epoch 12/50
# 41/41 [==============================] - ETA: 0s - loss: 0.5316 - accuracy: 0.7920
# Epoch 12: val_accuracy improved from 0.73006 to 0.75460, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 32s 787ms/step - loss: 0.5316 - accuracy: 0.7920 - val_loss: 0.5792 - val_accuracy: 0.7546
# Epoch 13/50
# 41/41 [==============================] - ETA: 0s - loss: 0.4568 - accuracy: 0.8303
# Epoch 13: val_accuracy improved from 0.75460 to 0.75767, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 34s 825ms/step - loss: 0.4568 - accuracy: 0.8303 - val_loss: 0.5849 - val_accuracy: 0.7577
# Epoch 14/50
# 41/41 [==============================] - ETA: 0s - loss: 0.4559 - accuracy: 0.8284
# Epoch 14: val_accuracy did not improve from 0.75767
# 41/41 [==============================] - 33s 817ms/step - loss: 0.4559 - accuracy: 0.8284 - val_loss: 0.5685 - val_accuracy: 0.7515
# Epoch 15/50
# 41/41 [==============================] - ETA: 0s - loss: 0.4098 - accuracy: 0.8495
# Epoch 15: val_accuracy improved from 0.75767 to 0.78221, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 33s 803ms/step - loss: 0.4098 - accuracy: 0.8495 - val_loss: 0.5529 - val_accuracy: 0.7822
# Epoch 16/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3678 - accuracy: 0.8698
# Epoch 16: val_accuracy improved from 0.78221 to 0.80368, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 32s 775ms/step - loss: 0.3678 - accuracy: 0.8698 - val_loss: 0.5314 - val_accuracy: 0.8037
# Epoch 17/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3701 - accuracy: 0.8648
# Epoch 17: val_accuracy did not improve from 0.80368
# 41/41 [==============================] - 30s 739ms/step - loss: 0.3701 - accuracy: 0.8648 - val_loss: 0.5637 - val_accuracy: 0.7853
# Epoch 18/50
# 41/41 [==============================] - ETA: 0s - loss: 0.3497 - accuracy: 0.8751
# Epoch 18: val_accuracy did not improve from 0.80368
# 41/41 [==============================] - 30s 712ms/step - loss: 0.3497 - accuracy: 0.8751 - val_loss: 0.5725 - val_accuracy: 0.8006
# Epoch 19/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2832 - accuracy: 0.9035
# Epoch 19: val_accuracy improved from 0.80368 to 0.80982, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 33s 821ms/step - loss: 0.2832 - accuracy: 0.9035 - val_loss: 0.5444 - val_accuracy: 0.8098
# Epoch 20/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2616 - accuracy: 0.9088
# Epoch 20: val_accuracy improved from 0.80982 to 0.83742, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 34s 817ms/step - loss: 0.2616 - accuracy: 0.9088 - val_loss: 0.4743 - val_accuracy: 0.8374
# Epoch 21/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2608 - accuracy: 0.9108
# Epoch 21: val_accuracy improved from 0.83742 to 0.84969, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 33s 805ms/step - loss: 0.2608 - accuracy: 0.9108 - val_loss: 0.4502 - val_accuracy: 0.8497
# Epoch 22/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2105 - accuracy: 0.9311
# Epoch 22: val_accuracy did not improve from 0.84969
# 41/41 [==============================] - 35s 864ms/step - loss: 0.2105 - accuracy: 0.9311 - val_loss: 0.4929 - val_accuracy: 0.8221
# Epoch 23/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2005 - accuracy: 0.9376
# Epoch 23: val_accuracy did not improve from 0.84969
# 41/41 [==============================] - 34s 828ms/step - loss: 0.2005 - accuracy: 0.9376 - val_loss: 0.5663 - val_accuracy: 0.8129
# Epoch 24/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2113 - accuracy: 0.9341
# Epoch 24: val_accuracy did not improve from 0.84969
# 41/41 [==============================] - 32s 769ms/step - loss: 0.2113 - accuracy: 0.9341 - val_loss: 0.5411 - val_accuracy: 0.8190
# Epoch 25/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1593 - accuracy: 0.9525
# Epoch 25: val_accuracy improved from 0.84969 to 0.85583, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 33s 805ms/step - loss: 0.1593 - accuracy: 0.9525 - val_loss: 0.4724 - val_accuracy: 0.8558
# Epoch 26/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1958 - accuracy: 0.9360
# Epoch 26: val_accuracy did not improve from 0.85583
# 41/41 [==============================] - 33s 790ms/step - loss: 0.1958 - accuracy: 0.9360 - val_loss: 0.4936 - val_accuracy: 0.8466
# Epoch 27/50
# 41/41 [==============================] - ETA: 0s - loss: 0.2246 - accuracy: 0.9280
# Epoch 27: val_accuracy did not improve from 0.85583
# 41/41 [==============================] - 33s 801ms/step - loss: 0.2246 - accuracy: 0.9280 - val_loss: 0.4806 - val_accuracy: 0.8466
# Epoch 28/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1403 - accuracy: 0.9575
# Epoch 28: val_accuracy improved from 0.85583 to 0.87117, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 33s 796ms/step - loss: 0.1403 - accuracy: 0.9575 - val_loss: 0.4799 - val_accuracy: 0.8712
# Epoch 29/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1132 - accuracy: 0.9651
# Epoch 29: val_accuracy did not improve from 0.87117
# 41/41 [==============================] - 33s 804ms/step - loss: 0.1132 - accuracy: 0.9651 - val_loss: 0.4773 - val_accuracy: 0.8712
# Epoch 30/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0932 - accuracy: 0.9724
# Epoch 30: val_accuracy did not improve from 0.87117
# 41/41 [==============================] - 35s 856ms/step - loss: 0.0932 - accuracy: 0.9724 - val_loss: 0.5415 - val_accuracy: 0.8589
# Epoch 31/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0990 - accuracy: 0.9709
# Epoch 31: val_accuracy did not improve from 0.87117
# 41/41 [==============================] - 33s 805ms/step - loss: 0.0990 - accuracy: 0.9709 - val_loss: 0.7015 - val_accuracy: 0.8313
# Epoch 32/50
# 41/41 [==============================] - ETA: 0s - loss: 0.1285 - accuracy: 0.9594
# Epoch 32: val_accuracy did not improve from 0.87117
# 41/41 [==============================] - 33s 804ms/step - loss: 0.1285 - accuracy: 0.9594 - val_loss: 0.4952 - val_accuracy: 0.8650
# Epoch 33/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0988 - accuracy: 0.9724
# Epoch 33: val_accuracy improved from 0.87117 to 0.87423, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 33s 825ms/step - loss: 0.0988 - accuracy: 0.9724 - val_loss: 0.4898 - val_accuracy: 0.8742
# Epoch 34/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0830 - accuracy: 0.9743
# Epoch 34: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 37s 889ms/step - loss: 0.0830 - accuracy: 0.9743 - val_loss: 0.5753 - val_accuracy: 0.8405
# Epoch 35/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0797 - accuracy: 0.9743
# Epoch 35: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 34s 830ms/step - loss: 0.0797 - accuracy: 0.9743 - val_loss: 0.5163 - val_accuracy: 0.8681
# Epoch 36/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9801
# Epoch 36: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 32s 767ms/step - loss: 0.0600 - accuracy: 0.9801 - val_loss: 0.5283 - val_accuracy: 0.8712
# Epoch 37/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0564 - accuracy: 0.9847
# Epoch 37: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 29s 707ms/step - loss: 0.0564 - accuracy: 0.9847 - val_loss: 0.5561 - val_accuracy: 0.8620
# Epoch 38/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0493 - accuracy: 0.9858
# Epoch 38: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 30s 709ms/step - loss: 0.0493 - accuracy: 0.9858 - val_loss: 0.6530 - val_accuracy: 0.8497
# Epoch 39/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0733 - accuracy: 0.9763
# Epoch 39: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 34s 842ms/step - loss: 0.0733 - accuracy: 0.9763 - val_loss: 0.5564 - val_accuracy: 0.8650
# Epoch 40/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0946 - accuracy: 0.9697
# Epoch 40: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 44s 1s/step - loss: 0.0946 - accuracy: 0.9697 - val_loss: 0.5123 - val_accuracy: 0.8681
# Epoch 41/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0411 - accuracy: 0.9885
# Epoch 41: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 42s 1s/step - loss: 0.0411 - accuracy: 0.9885 - val_loss: 0.6116 - val_accuracy: 0.8436
# Epoch 42/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0634 - accuracy: 0.9816
# Epoch 42: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 41s 1s/step - loss: 0.0634 - accuracy: 0.9816 - val_loss: 0.6415 - val_accuracy: 0.8558
# Epoch 43/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9801
# Epoch 43: val_accuracy did not improve from 0.87423
# 41/41 [==============================] - 39s 950ms/step - loss: 0.0672 - accuracy: 0.9801 - val_loss: 0.6511 - val_accuracy: 0.8497
# Epoch 44/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0945 - accuracy: 0.9686
# Epoch 44: val_accuracy improved from 0.87423 to 0.88344, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 37s 898ms/step - loss: 0.0945 - accuracy: 0.9686 - val_loss: 0.5118 - val_accuracy: 0.8834
# Epoch 45/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0519 - accuracy: 0.9854
# Epoch 45: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 35s 862ms/step - loss: 0.0519 - accuracy: 0.9854 - val_loss: 0.6220 - val_accuracy: 0.8558
# Epoch 46/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0585 - accuracy: 0.9847
# Epoch 46: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 34s 824ms/step - loss: 0.0585 - accuracy: 0.9847 - val_loss: 0.6172 - val_accuracy: 0.8374
# Epoch 47/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9862
# Epoch 47: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 31s 754ms/step - loss: 0.0469 - accuracy: 0.9862 - val_loss: 0.6572 - val_accuracy: 0.8650
# Epoch 48/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0357 - accuracy: 0.9908
# Epoch 48: val_accuracy did not improve from 0.88344
# 41/41 [==============================] - 32s 792ms/step - loss: 0.0357 - accuracy: 0.9908 - val_loss: 0.5398 - val_accuracy: 0.8712
# Epoch 49/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0241 - accuracy: 0.9939
# Epoch 49: val_accuracy improved from 0.88344 to 0.88650, saving model to bestomodel_LSTM.h5
# 41/41 [==============================] - 28s 687ms/step - loss: 0.0241 - accuracy: 0.9939 - val_loss: 0.4853 - val_accuracy: 0.8865
# Epoch 50/50
# 41/41 [==============================] - ETA: 0s - loss: 0.0151 - accuracy: 0.9973
# Epoch 50: val_accuracy did not improve from 0.88650
# 41/41 [==============================] - 32s 764ms/step - loss: 0.0151 - accuracy: 0.9973 - val_loss: 0.5251 - val_accuracy: 0.8742

# %%
test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 11/11 [==============================] - 1s 129ms/step - loss: 0.4479 - accuracy: 0.9021
# Test Accuracy: 0.9021406769752502

# %%
from tensorflow.keras.models import load_model
model = load_model('bestomodel_LSTM.h5')


test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Accuracy:", test_accuracy)
# Out:
# 11/11 [==============================] - 1s 59ms/step - loss: 0.4345 - accuracy: 0.8960
# Test Accuracy: 0.8960244655609131

# %%
import matplotlib.pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from sklearn.metrics import classification_report

test_loss, test_accuracy = model.evaluate(X_test, y_test)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)

predicted_probabilities = model.predict(X_test)
predicted_classes = np.argmax(predicted_probabilities, axis=1)

predicted_labels = label_encoder.inverse_transform(predicted_classes)
true_labels = label_encoder.inverse_transform(np.argmax(y_test, axis=1))

report = classification_report(true_labels, predicted_labels)
print(report)
# Out:
# 11/11 [==============================] - 1s 122ms/step - loss: 0.4345 - accuracy: 0.8960
# Test Loss: 0.43449559807777405
# Test Accuracy: 0.8960244655609131
# 11/11 [==============================] - 3s 118ms/step
#                   precision    recall  f1-score   support
#
#     glioma_tumor       0.91      0.83      0.87        93
# meningioma_tumor       0.87      0.89      0.88        93
#         no_tumor       0.89      0.85      0.87        55
#  pituitary_tumor       0.91      1.00      0.96        86
#
#         accuracy                           0.90       327
#        macro avg       0.90      0.89      0.89       327
#     weighted avg       0.90      0.90      0.89       327

# %%
from sklearn.metrics import roc_curve, auc
from sklearn.preprocessing import label_binarize
from itertools import cycle

n_classes = len(np.unique(true_labels))
binarized_true_labels = label_binarize(true_labels, classes=np.unique(true_labels))

fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(n_classes):
    fpr[i], tpr[i], _ = roc_curve(binarized_true_labels[:, i], predicted_probabilities[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(binarized_true_labels.ravel(), predicted_probabilities.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure()
lw = 2
for i in range(n_classes):
    plt.plot(fpr[i], tpr[i], lw=lw, label='ROC curve (area = %0.2f) for class %s' % (roc_auc[i], i))
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) curve')
plt.legend(loc="lower right")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import cv2
from tensorflow.keras.models import Model
import tensorflow as tf

sample_indices = np.random.choice(len(X_test), 5, replace=False)
sample_images = test_images_array[sample_indices]
sample_labels = true_labels[sample_indices]

sample_predicted_probabilities = model.predict(sample_images)
sample_predicted_labels = label_encoder.inverse_transform(np.argmax(sample_predicted_probabilities, axis=1))

plt.figure(figsize=(15, 10))
for i, (image, true_label, predicted_label) in enumerate(zip(sample_images, sample_labels, sample_predicted_labels)):
    plt.subplot(2, 5, i + 1)
    plt.imshow(image)
    plt.title(f"True: {true_label}\nPredicted: {predicted_label}")
    plt.axis('off')
plt.show()
# Out:
# 1/1 [==============================] - 1s 808ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

predicted_probabilities = model.predict(X_test)
class_names = ['glioma_tumor', 'meningioma_tumor', 'no_tumor', 'pituitary_tumor']
predicted_labels = np.argmax(predicted_probabilities, axis=1)

true_labels = np.argmax(y_test, axis=1)

cm = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix')
plt.xlabel('Predicted Labels')
plt.ylabel('True Labels')
plt.show()
# Out:
# 11/11 [==============================] - 1s 93ms/step
